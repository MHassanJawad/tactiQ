# %%
# 1) Mount Drive
from google.colab import drive
drive.mount('/content/drive')

# 2) Set your project path in Drive (change if different)
PROJECT_ROOT = "/content/drive/MyDrive/ML/project"

# 3) Move into project
import os, sys
os.chdir(PROJECT_ROOT)

# 4) Make imports like `python -m src...` work
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("cwd:", os.getcwd())
print("has src:", os.path.isdir("src"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 1) Mount Drive
# ----> 2 from google.colab import drive
#       3 drive.mount('/content/drive')
#       5 # 2) Set your project path in Drive (change if different)
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# !ls
# !ls open-data/data/matches/11
# !ls graphs | head
# Out:
# ML_Project_Proposal.docx
# PROJECT_TASKS.md
# README.md
# RT_FSAS_Presentation.pptx
# checkpoints
# colab.ipynb
# dashboard
# debug.log
# graphs
# index
# notebooks
# open-data
# open-data-master.zip.opdownload
# report
# rt-fsas-env
# scripts
# setup
# src
# 1.json
# 2.json
# 21.json
# 22.json
# 23.json
# 24.json
# 25.json
# 26.json
# 27.json
# 278.json
# 37.json
# 38.json
# 39.json
# 4.json
# 40.json
# 41.json
# 42.json
# 90.json
# la_liga_2015_16_full.pt
# la_liga_2015_16_full_shards
# la_liga_2015_16_train.pt
